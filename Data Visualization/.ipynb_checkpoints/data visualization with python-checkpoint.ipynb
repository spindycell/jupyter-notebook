# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
plt.plot(x,y)
plt.title("test plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
