# %% [markdown]
# # santika.analitika.karyanto.com

# %% [markdown]
# # Function List

# %%
import pandas as pd
import numpy as np
import csv

def load_csv(file_name):
    result = []
    with open(file_name,"r") as csvfile:
        reader = csv.reader(csvfile)

        for r in reader:
            result.append(r)
    return np.array(result)

def write_csv(file_name, data):
    with open(file_name, "w") as csvfile:
        writer = csv.writer(csvfile,quoting=csv.QUOTE_ALL)
        writer.writerow(data)

# %% [markdown]
# # Hitung jumlah user yang dicari dan top 5 user yang dicari

# %%
# Get data from instagram logs
data = pd.read_csv("instagram_logs.csv")

# Get user
nama = "|".join(data["username"].values)
nama = nama.split("|")
names, freqs = np.unique(nama, return_counts=True)
# print(names)
print("Total Unique Username dicari :",len(names))

print()

most_pop_user = np.array([(name, freq) for freq, name in sorted(zip(freqs, names), reverse=True)])[:5]
print("Top 5 user dicari: ", most_pop_user)

print()

# List data saat ini
data
# Out:
# Total Unique Username dicari : 18
#
# Top 5 user dicari:  [['raditya_dika' '197']
#  ['awkarin' '194']
#  ['milhamrk' '193']
#  ['emmaafifah99' '185']
#  ['emmaafifah' '185']]
#         id  instagram_user_id          username  followers  following  \
# 0        1                  1           awkarin    4391732        443
# 1        2                  2      raditya_dika   12522093        334
# 2        3                  3          milhamrk       1172        203
# 3        4                  1           awkarin    4391551        446
# 4        5                  1           awkarin    4391551        446
# 5        6                  2      raditya_dika   12546455        334
# 6        7                  2      raditya_dika   12546451        334
# 7        8                  3          milhamrk       1181        202
# 8        9                  3          milhamrk       1181        202
# 9       10                  1           awkarin    4391491        446
# 10      11                  1           awkarin    4391511        446
# 11      12                  2      raditya_dika   12546968        334
# 12      13                  2      raditya_dika   12546967        334
# 13      14                  3          milhamrk       1181        202
# 14      15                  3          milhamrk       1181        202
# 15      16                  1           awkarin    4391205        446
# 16      17                  2      raditya_dika   12552445        334
# 17      18                  3          milhamrk       1181        202
# 18      19                  4    selaras.travel        571       1615
# 19      20                  5        emmaafifah       1681        260
# 20      21                  6      emmaafifah99        268        695
# 21      22                  3          milhamrk       1181        202
# 22      23                  3          milhamrk       1181        202
# 23      24                  5        emmaafifah       1681        260
# 24      25                  5        emmaafifah       1681        260
# 25      26                  1           awkarin    4391170        446
# 26      27                  1           awkarin    4391170        446
# 27      28                  2      raditya_dika   12553036        334
# 28      29                  2      raditya_dika   12553036        334
# 29      30                  6      emmaafifah99        268        695
# ...    ...                ...               ...        ...        ...
# 2400  2401                 10             jkt48     291656         89
# 2401  2402                 17     ilhamkaryanto        828        111
# 2402  2403                 17     ilhamkaryanto        828        111
# 2403  2404                 15         spindyzel        479        671
# 2404  2405                 15         spindyzel        479        671
# 2405  2406                 18         pewdiepie   17014035        118
# 2406  2407                 18         pewdiepie   17014035        118
# 2407  2408                  1           awkarin    4411935        447
# 2408  2409                  1           awkarin    4411936        447
# 2409  2410                  8  garudarevolution     404447        910
# 2410  2411                  8  garudarevolution     404447        910
# 2411  2412                  2      raditya_dika   12732211        335
# 2412  2413                  2      raditya_dika   12732211        335
# 2413  2414                  6      emmaafifah99        269        696
# 2414  2415                  6      emmaafifah99        269        696
# # List Username

# %%
dataUser = []
#get only unique value
# dataTest = list(set(data["username"]))
for user in data["username"].values:
    if user not in dataTest:
        dataTest.append(user)

# print(dataTest)

write_csv("data_test.csv", dataTest)

searchUser = pd.read_csv("data_test.csv")

searchUser
# Out:
# Empty DataFrame
# Columns: [awkarin, raditya_dika, milhamrk, selaras.travel, emmaafifah, emmaafifah99, jokowi, garudarevolution, naufalfathinn, jkt48, undpindonesia, bryanerfandaputra, lambe_turah, crmegl, spindyzel, barcelona, ilhamkaryanto, pewdiepie]
# Index: []

# %% [markdown]
# # List Username dari uploads terbanyak

# %%
data.sort_values(["uploads"], ascending=[False], inplace=True) 

user_uploads = []

for user in data["username"].values:
    if user not in user_uploads:
        user_uploads.append(user)

write_csv("user_uploads.csv", user_uploads)

searchUploads = pd.read_csv("user_uploads.csv")

# Output hasil username dengan uploads terbanyak dari kiri ke kanan
searchUploads
# Out:
# Empty DataFrame
# Columns: [garudarevolution, lambe_turah, awkarin, raditya_dika, jokowi, undpindonesia, pewdiepie, jkt48, naufalfathinn, barcelona, selaras.travel, bryanerfandaputra, crmegl, spindyzel, emmaafifah, ilhamkaryanto, emmaafifah99, milhamrk]
# Index: []

# %% [markdown]
# # List Username dari followers terbanyak

# %%
data.sort_values(["followers"], ascending=[False], inplace=True) 

user_followers = []

for user in data["username"].values:
    if user not in user_followers:
        user_followers.append(user)

write_csv("user_followers.csv", user_followers)

searchFollowers = pd.read_csv("user_followers.csv")

# Output hasil username dengan FOLLOWERS terbanyak dari kiri ke kanan
searchFollowers
# Out:
# Empty DataFrame
# Columns: [jokowi, pewdiepie, raditya_dika, lambe_turah, awkarin, garudarevolution, jkt48, undpindonesia, barcelona, bryanerfandaputra, naufalfathinn, emmaafifah, milhamrk, ilhamkaryanto, selaras.travel, spindyzel, crmegl, emmaafifah99]
# Index: []

# %% [markdown]
# # List Username dari following terbanyak

# %%
data.sort_values(["following"], ascending=[False], inplace=True) 

user_following = []

for user in data["username"].values:
    if user not in user_following:
        user_following.append(user)

write_csv("user_following.csv", user_following)

searchFollowing = pd.read_csv("user_following.csv")

# Output hasil username dengan FOLLOWING terbanyak dari kiri ke kanan
searchFollowing
# Out:
# Empty DataFrame
# Columns: [selaras.travel, naufalfathinn, garudarevolution, emmaafifah99, bryanerfandaputra, spindyzel, awkarin, raditya_dika, emmaafifah, crmegl, milhamrk, pewdiepie, ilhamkaryanto, jkt48, undpindonesia, lambe_turah, barcelona, jokowi]
# Index: []

# %% [markdown]
# # Create new csv file dengan isi unique value (belom)

# %%
newData = load_csv("instagram_logs.csv")

print(newData)

dataBaru = []
# Out:
# [['id' 'instagram_user_id' 'username' ... 'following' 'uploads' 'date']
#  ['1' '1' 'awkarin' ... '443' '5170' '2019-04-23 03:36:07']
#  ['2' '2' 'raditya_dika' ... '334' '4039' '2019-04-23 04:02:40']
#  ...
#  ['2428' '15' 'spindyzel' ... '671' '15' '2019-05-12 01:20:02']
#  ['2429' '18' 'pewdiepie' ... '119' '739' '2019-05-12 01:30:02']
#  ['2430' '1' 'awkarin' ... '447' '5243' '2019-05-12 01:35:02']]
